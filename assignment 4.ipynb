# %% [markdown]
# 1. Read a Csv file and display the first 5 row of the dataset.

# %%
import pandas as pd

cv=pd.read_csv("C:/Users/LAB_101/Downloads/customers.csv")
cv.head()
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %% [markdown]
# 2. Specify which column should be used as the index when reading a csv file.

# %%
cv.set_index('Customer Id')
# Out:
#                  Index First Name Last Name                          Company  \
# Customer Id
# DD37Cf93aecA6Dc      1     Sheryl    Baxter                  Rasmussen Group
# 1Ef7b82A4CAAD10      2    Preston    Lozano                      Vega-Gentry
# 6F94879bDAfE5a6      3        Roy     Berry                    Murillo-Perry
# 5Cef8BFA16c5e3c      4      Linda     Olsen  Dominguez, Mcmillan and Donovan
# 053d585Ab6b3159      5     Joanna    Bender         Martin, Lang and Andrade
# ...                ...        ...       ...                              ...
# cb8E23e48d22Eae     96       Karl     Greer                        Carey LLC
# CeD220bdAaCfaDf     97       Lynn  Atkinson            Ware, Burns and Oneal
# 28CDbC0dFe4b1Db     98       Fred    Guerra                    Schmitt-Jones
# c23d1D9EE8DEB0A     99     Yvonne    Farmer               Fitzgerald-Harrell
# 2354a0E336A91A1    100   Clarence    Haynes               Le, Nash and Cross
#
# ...

# %% [markdown]
# 3. Read only specific columns from a csv file.

# %%
import pandas as pd

cv=pd.read_csv("C:/Users/LAB_101/Downloads/customers.csv",usecols=["Index",'First Name'])
cv
# Out:
#     Index First Name
# 0       1     Sheryl
# 1       2    Preston
# 2       3        Roy
# 3       4      Linda
# 4       5     Joanna
# ..    ...        ...
# 95     96       Karl
# 96     97       Lynn
# 97     98       Fred
# 98     99     Yvonne
# 99    100   Clarence
#
# [100 rows x 2 columns]

# %% [markdown]
# 4. skip a specific number of rows when reading a csv file.

# %%
import pandas as pd

cv=pd.read_csv("C:/Users/LAB_101/Downloads/customers.csv",skiprows=95)
cv
# Out:
#     95  BE91A0bdcA49Bbc   Darrell   Douglas Newton, Petersen and Mathis  \
# 0   96  cb8E23e48d22Eae      Karl     Greer                   Carey LLC
# 1   97  CeD220bdAaCfaDf      Lynn  Atkinson       Ware, Burns and Oneal
# 2   98  28CDbC0dFe4b1Db      Fred    Guerra               Schmitt-Jones
# 3   99  c23d1D9EE8DEB0A    Yvonne    Farmer          Fitzgerald-Harrell
# 4  100  2354a0E336A91A1  Clarence    Haynes          Le, Nash and Cross
#
#       Daisyborough             Mali 001-084-845-9524x1777  \
# 0     East Richard           Guyana   (188)169-1674x58692
# 1     New Bradview        Sri Lanka       +1-846-706-2218
# 2       Ortegaland  Solomon Islands  +1-753-067-8419x7170
# 3  Lake Elijahview            Aruba         (530)311-9786
# 4        Judymouth         Honduras         (753)813-6941
#
#          001-769-564-6303        grayjean@lowery-good.com  2022-02-17  \
# 0    001-841-293-3519x614                hhart@jensen.com  2022-01-30
# ...
